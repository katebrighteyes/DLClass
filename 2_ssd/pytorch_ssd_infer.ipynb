# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
cd gdrive/MyDrive/ssd/

# %%
pwd

# %%
cd pytorch-ssd/

# %%
import torch
print(torch.__version__)

# %%
ls

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# 이 중 하나의 모델 파일을 사용할 것입니다.

# %%
ls -al models/fruit

# %%
ls -al models/fruit/mb1-ssd-Epoch-29*

# %% [markdown]
# 이 중 Loss가 낮은 파일의 이름을 mb1-ssd-Epoch-29.pth 로 변경하세요.

# %%
mv models/fruit/mb1-ssd-Epoch-29-Loss-3.695290431380272.pth models/fruit/mb1-ssd-Epoch-29.pth

# %%
ls models/fruit/mb1-ssd-Epoch-29.pth

# %%
pwd

# %% [markdown]
# 파일 아이콘을 클릭하고 /content/gdrive/My Drive/ssd/pytorch-ssd/data/fruit/test/ 폴더의 이미지 하나를 testimage.jpg 로 rename 해줍니다.

# %%
ls data/fruit/test/testimage.jpg

# %%
imShow('data/fruit/test/testimage.jpg')

# %% [markdown]
# run_ssd_example.py 를 실행시키세요.

# %%
# !python3 run_ssd_example.py mb1-ssd models/fruit/mb1-ssd-Epoch-29.pth models/fruit/labels.txt data/fruit/test/testimage.jpg

# %%
imShow('run_ssd_example_output.jpg')

# %% [markdown]
# pre trained model 도 테스트해보겠습니다.

# %%
ls models/mobilenet-v1-ssd-mp-0_675.pth

# %% [markdown]
# 탐색기를 이용하여 models 폴더에 car.jpg 와 label.txt 를 업로드하세요.

# %%
imShow('models/car.jpg')

# %% [markdown]
# 이 labe 을 보면 모델에는 다음과 같은 데이터가 훈련되어 있습니다.
#
# aeroplane
# bicycle
# bird
# boat
# bottle
# bus
# car
# cat
# chair
# cow
# diningtable
# dog
# horse
# motorbike
# person
# pottedplant
# sheep
# sofa
# train
# tvmonitor

# %%
# !python3 run_ssd_example.py mb1-ssd models/mobilenet-v1-ssd-mp-0_675.pth models/labels.txt models/car.jpg

# %%
imShow('run_ssd_example_output.jpg')
